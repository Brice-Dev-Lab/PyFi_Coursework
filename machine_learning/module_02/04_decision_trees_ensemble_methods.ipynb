# %% [markdown]
# ![Decision Trees](images/01_decision.png)

# %% [markdown]
# ![Decision Trees](images/02_decision.png)

# %% [markdown]
# ![Decision Trees](images/03_decision.png)

# %% [markdown]
# ![Decision Trees](images/04_decision.png)

# %% [markdown]
# ![Decision Trees](images/05_decision.png)

# %% [markdown]
# ![Decision Trees](images/06_decision.png)
