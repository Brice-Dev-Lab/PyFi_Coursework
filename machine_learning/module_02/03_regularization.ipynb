# %% [markdown]
# ![Regularization](images/01_regularization.png)

# %% [markdown]
# ![Regularization](images/02_regularization.png)

# %% [markdown]
# ![Regularization](images/03_regularization.png)

# %% [markdown]
# ![Regularization](images/04_regularization.png)

# %% [markdown]
# ![Regularization](images/05_regularization.png)

# %% [markdown]
# ![Regularization](images/06_regularization.png)

# %% [markdown]
# ![Regularization](images/07_regularization.png)
