# %% [markdown]
# ![Real Relationships and Overfitting](images/01_real_relationships_overfitting.png)

# %% [markdown]
# ![Real Relationships and Overfitting](images/02_real_relationships_overfitting.png)

# %% [markdown]
# ![Real Relationships and Overfitting](images/03_real_relationships_overfitting.png)

# %% [markdown]
# ![Real Relationships and Overfitting](images/04_real_relationships_overfitting.png)

# %% [markdown]
# ![Real Relationships and Overfitting](images/05_real_relationships_overfitting.png)

# %% [markdown]
# ![Real Relationships and Overfitting](images/06_real_relationships_overfitting.png)

# %% [markdown]
# ![Real Relationships and Overfitting](images/07_real_relationships_overfitting.png)

# %% [markdown]
# ![Real Relationships and Overfitting](images/08_real_relationships_overfitting.png)
