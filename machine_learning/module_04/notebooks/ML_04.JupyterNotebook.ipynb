# %% [markdown]
# # Binary Classification with Logistic Regression

# %% [markdown]
# ![Classification](../images/01_classification.png)

# %% [markdown]
# ![Classification](../images/02_classification.png)

# %% [markdown]
# ![Classification](../images/03_classification.png)

# %% [markdown]
# # Logistic Regression Overview

# %% [markdown]
# ![Regression](../images/01_regression.png)

# %% [markdown]
# ![Regression](../images/02_regression.png)

# %% [markdown]
# # Decision Tree Classifier Overview

# %% [markdown]
# ![Decision Tree](../images/01_decision.png)
